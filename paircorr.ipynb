# %%
from gz_import import *
from gz_mainlib import *
from gz_plotlib import *
from gz_dwnllib import *
from gz_rwlib import *
from gz_const import *

mainver()
plotver()
rwver()
dwnlver()
constver()
# Out:
# Main ver: 67
# Plot ver: 67
# RW ver: 67
# Download ver: 67
# Const ver: 68

# %%
dfy = pd.read_hdf('dat.h5', 'dfy')
dfy_doclh = pd.read_hdf('dat.h5', 'dfy_doclh')
dfy_corr = pd.read_hdf('dat.h5', 'dfy_corr')

# %%
l_corr = []

for x,y in permutations(dfy_corr.columns[3:],2):
    indstr1 =  get_dictkey(d_industry_tics, x)
    indstr2 =  get_dictkey(d_industry_tics, y)
    #ret_x,risk_x,_ = return_risk_stock(dfy, x)
    #ret_y,risk_y,_ = return_risk_stock(dfy, y)
    
    corr = dfy_corr.loc[x, y]
    
    if x != y and corr > 0.8 and indstr1 == indstr2: 
        
        l_corr.append([x,y])
        # and risk_x > 0.7 corr < 0.85 and :
        #dfy_coint.loc[x,y] < 0.05: # and risk_x > 0.9:
        
        print(round(dfy_corr.loc[x, y], 2), x, y, indstr1, indstr2) #, round(risk_x,2), round(risk_y,2))
        
        #plot_LR_rel2tic_d(dfy, x, y)
# Out:
# 0.86 ADBE MSFT ['Software—Infrastructure'] ['Software—Infrastructure']
# 0.81 ADBE SNPS ['Software—Infrastructure'] ['Software—Infrastructure']
# 0.88 ALK DAL ['Airlines'] ['Airlines']
# 0.8 ALK HA ['Airlines'] ['Airlines']
# 0.84 ALK LUV ['Airlines'] ['Airlines']
# 0.87 ALK SAVE ['Airlines'] ['Airlines']
# 0.87 ALK UAL ['Airlines'] ['Airlines']
# 0.93 AMAT LRCX ['Semiconductor Equipment & Materials'] ['Semiconductor Equipment & Materials']
# 0.86 AMAT TER ['Semiconductor Equipment & Materials'] ['Semiconductor Equipment & Materials']
# 0.81 APA DVN ['Oil & Gas E&P'] ['Oil & Gas E&P']
# 0.81 APA OXY ['Oil & Gas E&P'] ['Oil & Gas E&P']
# 0.83 AVGO TXN ['Semiconductors'] ['Semiconductors']
# 0.87 AXP DFS ['Credit Services'] ['Credit Services']
# 0.83 BJRI DRI ['Restaurants'] ['Restaurants']
# 0.86 BA SPR ['Aerospace & Defense'] ['Aerospace & Defense']
# 0.81 BKNG EXPE ['Travel Services'] ['Travel Services']
# 0.92 BAC C ['Banks—Diversified'] ['Banks—Diversified']
# 0.95 BAC JPM ['Banks—Diversified'] ['Banks—Diversified']
# 0.9 BAC WFC ['Banks—Diversified'] ['Banks—Diversified']
# 0.81 BKR HAL ['Oil & Gas Equipment & Services'] ['Oil & Gas Equipment & Services']
# 0.85 BKR SLB ['Oil & Gas Equipment & Services'] ['Oil & Gas Equipment & Services']
# 0.81 BSX MDT ['Medical Devices'] ['Medical Devices']
# 0.81 CHEF USFD ['Food Distribution'] ['Food Distribution']
# 0.92 C BAC ['Banks—Diversified'] ['Banks—Diversified']
# 0.91 C JPM ['Banks—Diversified'] ['Banks—Diversified']
# 0.86 C WFC ['Banks—Diversified'] ['Banks—Diversified']
# 0.8 EOG OVV ['Oil & Gas E&P'] ['Oil & Gas E&P']
# 1.0 GOOGL GOOG ['Internet Content & Information'] ['Internet Content & Information']
# 1.0 GOOG GOOGL ['Internet Content & Information'] ['Internet Content & Information']
# 0.91 GS MS ['Capital Markets'] ['Capital Markets']
# 0.8 HA ALK ['Airlines'] ['Airlines']
# 0.84 HA DAL ['Airlines'] ['Airlines']
# 0.87 H HLT ['Lodging'] ['Lodging']
# 0.88 H MAR ['Lodging'] ['Lodging']
# 0.9 HBAN CFG ['Banks—Regional'] ['Banks—Regional']
# 0.91 HBAN KEY ['Banks—Regional'] ['Banks—Regional']
# 0.84 HBAN PBCT ['Banks—Regional'] ['Banks—Regional']
# 0.9 HBAN RF ['Banks—Regional'] ['Banks—Regional']
# 0.91 HBAN USB ['Banks—Regional'] ['Banks—Regional']
# 0.81 HAL BKR ['Oil & Gas Equipment & Services'] ['Oil & Gas Equipment & Services']
# 0.89 HAL SLB ['Oil & Gas Equipment & Services'] ['Oil & Gas Equipment & Services']
# 0.89 HD LOW ['Home Improvement Retail'] ['Home Improvement Retail']
# 0.84 HON EMR ['Specialty Industrial Machinery'] ['Specialty Industrial Machinery']
# 0.87 HLT H ['Lodging'] ['Lodging']
# 0.89 HLT MAR ['Lodging'] ['Lodging']
# 0.95 JPM BAC ['Banks—Diversified'] ['Banks—Diversified']
# 0.91 JPM C ['Banks—Diversified'] ['Banks—Diversified']
# 0.87 JPM WFC ['Banks—Diversified'] ['Banks—Diversified']
# 0.82 JWN M ['Department Stores'] ['Department Stores']
# 0.85 KBH DHI ['Residential Construction'] ['Residential Construction']
# 0.87 KBH LEN ['Residential Construction'] ['Residential Construction']
# 0.9 KBH PHM ['Residential Construction'] ['Residential Construction']
# 0.82 LGIH DHI ['Residential Construction'] ['Residential Construction']
# 0.81 LGIH LEN ['Residential Construction'] ['Residential Construction']
# 0.8 LGIH PHM ['Residential Construction'] ['Residential Construction']
# 0.86 LHX LMT ['Aerospace & Defense'] ['Aerospace & Defense']
# 0.96 KEY CFG ['Banks—Regional'] ['Banks—Regional']
# 0.91 KEY HBAN ['Banks—Regional'] ['Banks—Regional']
# 0.95 KEY RF ['Banks—Regional'] ['Banks—Regional']
# 0.89 KEY USB ['Banks—Regional'] ['Banks—Regional']
# 0.89 LOW HD ['Home Improvement Retail'] ['Home Improvement Retail']
# 0.83 KMI OKE ['Oil & Gas Midstream'] ['Oil & Gas Midstream']
# 0.83 KMI WMB ['Oil & Gas Midstream'] ['Oil & Gas Midstream']
# 0.93 LRCX AMAT ['Semiconductor Equipment & Materials'] ['Semiconductor Equipment & Materials']
# 0.87 LRCX TER ['Semiconductor Equipment & Materials'] ['Semiconductor Equipment & Materials']
# 0.84 LUV ALK ['Airlines'] ['Airlines']
# 0.85 LUV DAL ['Airlines'] ['Airlines']
# 0.81 LUV SAVE ['Airlines'] ['Airlines']
# 0.81 LUV UAL ['Airlines'] ['Airlines']
# 0.92 LEN DHI ['Residential Construction'] ['Residential Construction']
# 0.87 PSX MPC ['Oil & Gas Refining & Marketing'] ['Oil & Gas Refining & Marketing']
# 0.81 PSX PBF ['Oil & Gas Refining & Marketing'] ['Oil & Gas Refining & Marketing']
# 0.93 PSX VLO ['Oil & Gas Refining & Marketing'] ['Oil & Gas Refining & Marketing']
# 0.81 PPL SO ['Utilities—Regulated Electric'] ['Utilities—Regulated Electric']
# 0.95 PRU MET ['Insurance—Life'] ['Insurance—Life']
# 0.8 PVH CPRI ['Apparel Manufacturing'] ['Apparel Manufacturing']
# 0.81 PVH RL ['Apparel Manufacturing'] ['Apparel Manufacturing']
# 0.84 QCOM QRVO ['Semiconductors'] ['Semiconductors']
# 0.84 QRVO QCOM ['Semiconductors'] ['Semiconductors']
# 0.82 QRVO TXN ['Semiconductors'] ['Semiconductors']
# 0.95 RF CFG ['Banks—Regional'] ['Banks—Regional']
# 0.9 RF HBAN ['Banks—Regional'] ['Banks—Regional']
# 0.95 RF KEY ['Banks—Regional'] ['Banks—Regional']
# 0.8 RF PBCT ['Banks—Regional'] ['Banks—Regional']
# 0.88 RF USB ['Banks—Regional'] ['Banks—Regional']
# 0.89 RCL CCL ['Travel Services'] ['Travel Services']
# 0.81 RL PVH ['Apparel Manufacturing'] ['Apparel Manufacturing']
# 0.85 ROST TJX ['Apparel Retail'] ['Apparel Retail']
# 0.87 SAVE ALK ['Airlines'] ['Airlines']
# 0.86 SAVE DAL ['Airlines'] ['Airlines']
# 0.81 SAVE LUV ['Airlines'] ['Airlines']
# 0.87 SAVE UAL ['Airlines'] ['Airlines']
# 0.8 SEDG ENPH ['Solar'] ['Solar']
# 0.81 SNPS ADBE ['Software—Infrastructure'] ['Software—Infrastructure']
# 0.82 SNPS MSFT ['Software—Infrastructure'] ['Software—Infrastructure']
# 0.86 SPR BA ['Aerospace & Defense'] ['Aerospace & Defense']
# 0.8 SPG MAC ['REIT—Retail'] ['REIT—Retail']
# 0.82 SPG KIM ['REIT—Retail'] ['REIT—Retail']
# 0.86 SO D ['Utilities—Regulated Electric'] ['Utilities—Regulated Electric']
# 0.83 SO ED ['Utilities—Regulated Electric'] ['Utilities—Regulated Electric']
# 0.81 SO NEE ['Utilities—Regulated Electric'] ['Utilities—Regulated Electric']
# 0.81 SO PPL ['Utilities—Regulated Electric'] ['Utilities—Regulated Electric']
# 0.85 SLB BKR ['Oil & Gas Equipment & Services'] ['Oil & Gas Equipment & Services']
# 0.89 SLB HAL ['Oil & Gas Equipment & Services'] ['Oil & Gas Equipment & Services']
# 0.8 SLB OII ['Oil & Gas Equipment & Services'] ['Oil & Gas Equipment & Services']
# 0.83 SYY PFGC ['Food Distribution'] ['Food Distribution']
# 0.88 SYY USFD ['Food Distribution'] ['Food Distribution']
# 0.86 TER AMAT ['Semiconductor Equipment & Materials'] ['Semiconductor Equipment & Materials']
# 0.87 TER LRCX ['Semiconductor Equipment & Materials'] ['Semiconductor Equipment & Materials']
# 0.85 TJX ROST ['Apparel Retail'] ['Apparel Retail']
# 0.87 UAL ALK ['Airlines'] ['Airlines']
# 0.92 UAL DAL ['Airlines'] ['Airlines']
# 0.81 UAL LUV ['Airlines'] ['Airlines']
# 0.87 UAL SAVE ['Airlines'] ['Airlines']
# 0.83 TXN AVGO ['Semiconductors'] ['Semiconductors']
# 0.82 TXN QRVO ['Semiconductors'] ['Semiconductors']
# 0.81 USFD CHEF ['Food Distribution'] ['Food Distribution']
# 0.85 USFD PFGC ['Food Distribution'] ['Food Distribution']
# 0.88 USFD SYY ['Food Distribution'] ['Food Distribution']
# 0.93 V MA ['Credit Services'] ['Credit Services']
# 0.89 VLO MPC ['Oil & Gas Refining & Marketing'] ['Oil & Gas Refining & Marketing']
# 0.83 VLO PBF ['Oil & Gas Refining & Marketing'] ['Oil & Gas Refining & Marketing']
# 0.93 VLO PSX ['Oil & Gas Refining & Marketing'] ['Oil & Gas Refining & Marketing']
# 0.88 USB CFG ['Banks—Regional'] ['Banks—Regional']
# 0.91 USB HBAN ['Banks—Regional'] ['Banks—Regional']
# 0.89 USB KEY ['Banks—Regional'] ['Banks—Regional']
# 0.84 USB PBCT ['Banks—Regional'] ['Banks—Regional']
# 0.88 USB RF ['Banks—Regional'] ['Banks—Regional']
# 0.9 WFC BAC ['Banks—Diversified'] ['Banks—Diversified']
# 0.86 WFC C ['Banks—Diversified'] ['Banks—Diversified']
# 0.87 WFC JPM ['Banks—Diversified'] ['Banks—Diversified']
# 0.86 WYNN LVS ['Resorts & Casinos'] ['Resorts & Casinos']
# 0.9 VTR WELL ['REIT—Healthcare Facilities'] ['REIT—Healthcare Facilities']
# 0.9 WELL VTR ['REIT—Healthcare Facilities'] ['REIT—Healthcare Facilities']
# 0.85 STAG DRE ['REIT—Industrial'] ['REIT—Industrial']
# 0.87 XOM CVX ['Oil & Gas Integrated'] ['Oil & Gas Integrated']
# 0.83 WMB KMI ['Oil & Gas Midstream'] ['Oil & Gas Midstream']
# 0.82 KIM SPG ['REIT—Retail'] ['REIT—Retail']
# 0.85 DRE STAG ['REIT—Industrial'] ['REIT—Industrial']

# %%
l_corrrest = sorted(list(set(sum(l_corr, []))))

# %%
temp = dfy_doclh.copy()
temp_shift1 = temp.shift(1)

#temp - temp.shift(1)
droplist1 = []
ren1 = {}

for x in temp.columns[1:]:
    if '_close' not in x:
        droplist1.append(x) 
    elif '_close' in x:
        ren1.update({x:x.replace('_close','')})

        
droplist2 = []
ren2 = {}
for x in temp_shift1.columns[1:]:
    if '_close' not in x:
        droplist2.append(x) 
    elif '_close' in x:
        ren2.update({x:x.replace('_close','')})

        
temp.drop(droplist1, axis=1, inplace=True)      
temp.rename(ren1, axis=1, inplace=True)
temp_shift1.drop(droplist2, axis=1, inplace=True)        
temp_shift1.rename(ren2, axis=1, inplace=True)
1
# Out:
# 1

# %%
#set(list(df_res.columns))

# %%
#l_dff = set(l_corrrest) ^ set(list(df_res.columns))

# %%
df_res =  temp[['date']].join((temp_shift1.iloc[:,1:] - temp.iloc[:,1:])/ temp.iloc[:,1:]).dropna()
#df_res

# %%
for e in l_corr:
# 3      0.000986
# 4     -0.003875
# 5      0.005255
# ..          ...
# 383    0.003372
# 384    0.005073
# 385   -0.003275
# 386    0.000925
# 387    0.008699
#
# [387 rows x 576 columns]

# %%
sorted(df_res.drop(l_dff, axis=1).columns)
# Out:
# ['ADBE',
#  'ALK',
#  'AMAT',
#  'APA',
#  'AVGO',
#  'AXP',
#  'BA',
#  'BAC',
#  'BJRI',
#  'BKNG',
#  'BKR',
#  'BSX',
#  'C',
#  'CCL',
#  'CFG',
#  'CHEF',
#  'CLR',
#  'COP',
#  'CPRI',
#  'CVX',
#  'D',
#  'DAL',
#  'DFS',
#  'DHI',
#  'DRE',
#  'DRI',
#  'DVN',
#  'ED',
#  'EMR',
#  'ENPH',
#  'EOG',
#  'EXPE',
#  'GOOG',
#  'GOOGL',
#  'GS',
#  'H',
#  'HA',
#  'HAL',
#  'HBAN',
#  'HD',
#  'HLT',
#  'HON',
#  'JPM',
#  'JWN',
#  'KBH',
#  'KEY',
#  'KIM',
#  'KMI',
#  'LEN',
#  'LGIH',
#  'LHX',
#  'LMT',
#  'LOW',
#  'LRCX',
#  'LUV',
#  'LVS',
#  'M',
#  'MA',
#  'MAC',
#  'MAR',
#  'MDT',
#  'MET',
#  'MPC',
#  'MS',
#  'MSFT',
#  'NEE',
#  'OII',
#  'OKE',
#  'OVV',
#  'OXY',
#  'PBCT',
#  'PBF',
#  'PFGC',
#  'PHM',
#  'PPL',
#  'PRU',
#  'PSX',
#  'PVH',
#  'QCOM',
#  'QRVO',
#  'RCL',
#  'RF',
#  'RL',
#  'ROST',
#  'SAVE',
#  'SEDG',
#  'SLB',
#  'SNPS',
#  'SO',
#  'SPG',
#  'SPR',
#  'STAG',
#  'SYY',
#  'TER',
#  'TJX',
#  'TXN',
#  'UAL',
#  'USB',
#  'USFD',
#  'V',
#  'VLO',
#  'VTR',
#  'WELL',
#  'WFC',
#  'WMB',
#  'WYNN',
#  'XOM']

# %%
l_corr
# Out:
# [['ADBE', 'MSFT'],
#  ['ADBE', 'SNPS'],
#  ['ALK', 'DAL'],
#  ['ALK', 'HA'],
#  ['ALK', 'LUV'],
#  ['ALK', 'SAVE'],
#  ['ALK', 'UAL'],
#  ['AMAT', 'LRCX'],
#  ['AMAT', 'TER'],
#  ['APA', 'DVN'],
#  ['APA', 'OXY'],
#  ['AVGO', 'TXN'],
#  ['AXP', 'DFS'],
#  ['BJRI', 'DRI'],
#  ['BA', 'SPR'],
#  ['BKNG', 'EXPE'],
#  ['BAC', 'C'],
#  ['BAC', 'JPM'],
#  ['BAC', 'WFC'],
#  ['BKR', 'HAL'],
#  ['BKR', 'SLB'],
#  ['BSX', 'MDT'],
#  ['CHEF', 'USFD'],
#  ['C', 'BAC'],
#  ['C', 'JPM'],
#  ['C', 'WFC'],
#  ['CCL', 'RCL'],
#  ['CFG', 'HBAN'],
#  ['CFG', 'KEY'],
#  ['CFG', 'RF'],
#  ['CFG', 'USB'],
#  ['CLR', 'DVN'],
#  ['CLR', 'EOG'],
#  ['CLR', 'OXY'],
#  ['CLR', 'OVV'],
#  ['CPRI', 'PVH'],
#  ['COP', 'DVN'],
#  ['COP', 'EOG'],
#  ['COP', 'OXY'],
#  ['D', 'ED'],
#  ['D', 'SO'],
#  ['DAL', 'ALK'],
#  ['DAL', 'HA'],
#  ['DAL', 'LUV'],
#  ['DAL', 'SAVE'],
#  ['DAL', 'UAL'],
#  ['CVX', 'XOM'],
#  ['DFS', 'AXP'],
#  ['DHI', 'KBH'],
#  ['DHI', 'LGIH'],
#  ['DHI', 'LEN'],
#  ['DHI', 'PHM'],
#  ['DRI', 'BJRI'],
#  ['DVN', 'APA'],
#  ['DVN', 'CLR'],
#  ['DVN', 'COP'],
#  ['DVN', 'EOG'],
#  ['DVN', 'OXY'],
#  ['DVN', 'OVV'],
#  ['ED', 'D'],
#  ['ED', 'SO'],
#  ['ENPH', 'SEDG'],
#  ['EXPE', 'BKNG'],
#  ['EMR', 'HON'],
#  ['EOG', 'CLR'],
#  ['EOG', 'COP'],
#  ['EOG', 'DVN'],
#  ['EOG', 'OXY'],
#  ['EOG', 'OVV'],
#  ['GOOGL', 'GOOG'],
#  ['GOOG', 'GOOGL'],
#  ['GS', 'MS'],
#  ['HA', 'ALK'],
#  ['HA', 'DAL'],
#  ['H', 'HLT'],
#  ['H', 'MAR'],
#  ['HBAN', 'CFG'],
#  ['HBAN', 'KEY'],
#  ['HBAN', 'PBCT'],
#  ['HBAN', 'RF'],
#  ['HBAN', 'USB'],
#  ['HAL', 'BKR'],
#  ['HAL', 'SLB'],
#  ['HD', 'LOW'],
#  ['HON', 'EMR'],
#  ['HLT', 'H'],
#  ['HLT', 'MAR'],
#  ['JPM', 'BAC'],
#  ['JPM', 'C'],
#  ['JPM', 'WFC'],
#  ['JWN', 'M'],
#  ['KBH', 'DHI'],
#  ['KBH', 'LEN'],
#  ['KBH', 'PHM'],
#  ['LGIH', 'DHI'],
#  ['LGIH', 'LEN'],
#  ['LGIH', 'PHM'],
#  ['LHX', 'LMT'],
#  ['KEY', 'CFG'],
#  ['KEY', 'HBAN'],
#  ['KEY', 'RF'],
#  ['KEY', 'USB'],
#  ['LOW', 'HD'],
#  ['KMI', 'OKE'],
#  ['KMI', 'WMB'],
#  ['LRCX', 'AMAT'],
#  ['LRCX', 'TER'],
#  ['LUV', 'ALK'],
#  ['LUV', 'DAL'],
#  ['LUV', 'SAVE'],
#  ['LUV', 'UAL'],
#  ['LEN', 'DHI'],
#  ['LEN', 'KBH'],
#  ['LEN', 'LGIH'],
#  ['LEN', 'PHM'],
#  ['LMT', 'LHX'],
#  ['MA', 'V'],
#  ['LVS', 'WYNN'],
#  ['MAR', 'H'],
#  ['MAR', 'HLT'],
#  ['M', 'JWN'],
#  ['MAC', 'SPG'],
#  ['MET', 'PRU'],
#  ['MDT', 'BSX'],
#  ['MPC', 'PSX'],
#  ['MPC', 'VLO'],
#  ['MS', 'GS'],
#  ['MSFT', 'ADBE'],
#  ['MSFT', 'SNPS'],
#  ['NEE', 'SO'],
#  ['OII', 'SLB'],
#  ['OKE', 'KMI'],
#  ['OXY', 'APA'],
#  ['OXY', 'CLR'],
#  ['OXY', 'COP'],
#  ['OXY', 'DVN'],
#  ['OXY', 'EOG'],
#  ['OXY', 'OVV'],
#  ['OVV', 'CLR'],
#  ['OVV', 'DVN'],
#  ['OVV', 'EOG'],
#  ['OVV', 'OXY'],
#  ['PBF', 'PSX'],
#  ['PBF', 'VLO'],
#  ['PBCT', 'HBAN'],
#  ['PBCT', 'RF'],
#  ['PBCT', 'USB'],
#  ['PFGC', 'SYY'],
#  ['PFGC', 'USFD'],
#  ['PHM', 'DHI'],
#  ['PHM', 'KBH'],
#  ['PHM', 'LGIH'],
#  ['PHM', 'LEN'],
#  ['PSX', 'MPC'],
#  ['PSX', 'PBF'],
#  ['PSX', 'VLO'],
#  ['PPL', 'SO'],
#  ['PRU', 'MET'],
#  ['PVH', 'CPRI'],
#  ['PVH', 'RL'],
#  ['QCOM', 'QRVO'],
#  ['QRVO', 'QCOM'],
#  ['QRVO', 'TXN'],
#  ['RF', 'CFG'],
#  ['RF', 'HBAN'],
#  ['RF', 'KEY'],
#  ['RF', 'PBCT'],
#  ['RF', 'USB'],
#  ['RCL', 'CCL'],
#  ['RL', 'PVH'],
#  ['ROST', 'TJX'],
#  ['SAVE', 'ALK'],
#  ['SAVE', 'DAL'],
#  ['SAVE', 'LUV'],
#  ['SAVE', 'UAL'],
#  ['SEDG', 'ENPH'],
#  ['SNPS', 'ADBE'],
#  ['SNPS', 'MSFT'],
#  ['SPR', 'BA'],
#  ['SPG', 'MAC'],
#  ['SPG', 'KIM'],
#  ['SO', 'D'],
#  ['SO', 'ED'],
#  ['SO', 'NEE'],
#  ['SO', 'PPL'],
#  ['SLB', 'BKR'],
#  ['SLB', 'HAL'],
#  ['SLB', 'OII'],
#  ['SYY', 'PFGC'],
#  ['SYY', 'USFD'],
#  ['TER', 'AMAT'],
#  ['TER', 'LRCX'],
#  ['TJX', 'ROST'],
#  ['UAL', 'ALK'],
#  ['UAL', 'DAL'],
#  ['UAL', 'LUV'],
#  ['UAL', 'SAVE'],
#  ['TXN', 'AVGO'],
#  ['TXN', 'QRVO'],
#  ['USFD', 'CHEF'],
#  ['USFD', 'PFGC'],
#  ['USFD', 'SYY'],
#  ['V', 'MA'],
#  ['VLO', 'MPC'],
#  ['VLO', 'PBF'],
#  ['VLO', 'PSX'],
#  ['USB', 'CFG'],
#  ['USB', 'HBAN'],
#  ['USB', 'KEY'],
#  ['USB', 'PBCT'],
#  ['USB', 'RF'],
#  ['WFC', 'BAC'],
#  ['WFC', 'C'],
#  ['WFC', 'JPM'],
#  ['WYNN', 'LVS'],
#  ['VTR', 'WELL'],
#  ['WELL', 'VTR'],
#  ['STAG', 'DRE'],
#  ['XOM', 'CVX'],
#  ['WMB', 'KMI'],
#  ['KIM', 'SPG'],
#  ['DRE', 'STAG']]

# %%
len(df_res[df_res['AAPL'] > 0.02][['AAPL']])
# Out:
# 103

# %%
len(dfy)
# Out:
# 385

# %%
d_res = df_res[df_res.iloc[:,1:] > 0.05].count().to_dict()

# %%
#sorted(d_res.items())
#df_res[-50:]

# %%
df_res2 = df_res[-50:]
d_res2 = df_res2[df_res2.iloc[:,1:] < -0.01].count().to_dict()
{k: v for k, v in sorted(d_res2.items(), key=lambda item: item[1])}
# Out:
# {'date': 0,
#  'ED': 0,
#  'MCD': 0,
#  'TSN': 0,
#  'YUM': 0,
#  'VZ': 0,
#  'WM': 0,
#  'EXC': 1,
#  'GPN': 1,
#  'HAS': 1,
#  'KHC': 1,
#  'KMB': 1,
#  'KO': 1,
#  'LMT': 1,
#  'MAS': 1,
#  'MDLZ': 1,
#  'MDT': 1,
#  'SO': 1,
#  'WU': 1,
#  'SXT': 1,
#  'ABBV': 2,
#  'BKNG': 2,
#  'BLL': 2,
#  'BMY': 2,
#  'CNP': 2,
#  'GD': 2,
#  'HD': 2,
#  'JNJ': 2,
#  'LOW': 2,
#  'MLCO': 2,
#  'MPC': 2,
#  'MMM': 2,
#  'NEE': 2,
#  'OMC': 2,
#  'PEP': 2,
#  'PHM': 2,
#  'PPL': 2,
#  'T': 2,
#  'TRIP': 2,
#  'YY': 2,
#  'V': 2,
#  'WMT': 2,
#  'LSTR': 2,
#  'ABT': 3,
#  'ADM': 3,
#  'ALXN': 3,
#  'BSX': 3,
#  'BUD': 3,
#  'BTI': 3,
#  'CSCO': 3,
#  'D': 3,
#  'DHI': 3,
#  'DISCA': 3,
#  'EHTH': 3,
#  'EIX': 3,
#  'GLW': 3,
#  'HIG': 3,
#  'HII': 3,
#  'HON': 3,
#  'HPQ': 3,
#  'IBM': 3,
#  'INCY': 3,
#  'INGR': 3,
#  'INTC': 3,
#  'LUV': 3,
#  'MNST': 3,
#  'NEM': 3,
#  'PG': 3,
#  'SBUX': 3,
#  'RTX': 3,
#  'SPGI': 3,
#  'UPS': 3,
#  'WBA': 3,
#  'UNH': 3,
#  'WYNN': 3,
#  'ADSK': 4,
#  'AMGN': 4,
#  'AMT': 4,
#  'ATVI': 4,
#  'AXP': 4,
#  'CAT': 4,
#  'CME': 4,
#  'CMCSA': 4,
#  'CRM': 4,
#  'CTXS': 4,
#  'DAL': 4,
#  'CVS': 4,
#  'EA': 4,
#  'FDX': 4,
#  'GRMN': 4,
#  'HOG': 4,
#  'IRBT': 4,
#  'JOYY': 4,
#  'KMI': 4,
#  'JPM': 4,
#  'MA': 4,
#  'LHX': 4,
#  'MO': 4,
#  'NFLX': 4,
#  'O': 4,
#  'PBCT': 4,
#  'PM': 4,
#  'RACE': 4,
#  'QRVO': 4,
#  'RF': 4,
#  'SP': 4,
#  'SYY': 4,
#  'TTWO': 4,
#  'TJX': 4,
#  'VRTX': 4,
#  'USB': 4,
#  'ACN': 5,
#  'ANAB': 5,
#  'ALK': 5,
#  'ARE': 5,
#  'BAC': 5,
#  'BJRI': 5,
#  'CCL': 5,
#  'CVX': 5,
#  'DIS': 5,
#  'GILD': 5,
#  'GOSS': 5,
#  'EXPE': 5,
#  'GOOGL': 5,
#  'GOOG': 5,
#  'GE': 5,
#  'H': 5,
#  'HCA': 5,
#  'HPE': 5,
#  'JCOM': 5,
#  'KBH': 5,
#  'KR': 5,
#  'LVS': 5,
#  'MBT': 5,
#  'MSFT': 5,
#  'MRK': 5,
#  'NDAQ': 5,
#  'PPC': 5,
#  'RL': 5,
#  'SAVE': 5,
#  'SCHW': 5,
#  'SNY': 5,
#  'UBER': 5,
#  'WRK': 5,
#  'WMB': 5,
#  'XRX': 5,
#  'EXPD': 5,
#  'DRE': 5,
#  'ABMD': 6,
#  'AMD': 6,
#  'AVGO': 6,
#  'AMZN': 6,
#  'AYX': 6,
#  'BABA': 6,
#  'BK': 6,
#  'BBY': 6,
#  'BIIB': 6,
#  'CAH': 6,
#  'DHR': 6,
#  'ENDP': 6,
#  'EPAM': 6,
#  'FNKO': 6,
#  'HA': 6,
#  'HEAR': 6,
#  'JP': 6,
#  'IVZ': 6,
#  'LEN': 6,
#  'MET': 6,
#  'NTES': 6,
#  'OKE': 6,
#  'NKE': 6,
#  'ORCL': 6,
#  'PRU': 6,
#  'PYPL': 6,
#  'QCOM': 6,
#  'REGN': 6,
#  'ROST': 6,
#  'RRGB': 6,
#  'SHI': 6,
#  'SPG': 6,
#  'STX': 6,
#  'TDOC': 6,
#  'TMUS': 6,
#  'TGT': 6,
#  'TSLA': 6,
#  'TSM': 6,
#  'TOT': 6,
#  'TROW': 6,
#  'UAL': 6,
#  'WDC': 6,
#  'TXN': 6,
#  'VTR': 6,
#  'ZYXI': 6,
#  'WFC': 6,
#  'SP500': 7,
#  'AAPL': 7,
#  'AERI': 7,
#  'ADS': 7,
#  'ATRA': 7,
#  'BA': 7,
#  'C': 7,
#  'COTY': 7,
#  'DKNG': 7,
#  'DOW': 7,
#  'EMR': 7,
#  'FB': 7,
#  'EVH': 7,
#  'FCX': 7,
#  'GM': 7,
#  'GPS': 7,
#  'GT': 7,
#  'IBN': 7,
#  'IRM': 7,
#  'JD': 7,
#  'JWN': 7,
#  'LEVI': 7,
#  'LYB': 7,
#  'MAR': 7,
#  'LLY': 7,
#  'MSTR': 7,
#  'NTAP': 7,
#  'PCG': 7,
#  'PBF': 7,
#  'PFGC': 7,
#  'PSX': 7,
#  'RCL': 7,
#  'SNPS': 7,
#  'SWN': 7,
#  'SQ': 7,
#  'TAL': 7,
#  'UAA': 7,
#  'VREX': 7,
#  'VEON': 7,
#  'Z': 7,
#  'VLO': 7,
#  'WELL': 7,
#  'ZGNX': 7,
#  'XLNX': 7,
#  'STAG': 7,
#  'KIM': 7,
#  'ZS': 7,
#  'XOM': 7,
#  'ADBE': 8,
#  'AIG': 8,
#  'APA': 8,
#  'BEN': 8,
#  'CFG': 8,
#  'CNK': 8,
#  'CNC': 8,
#  'COP': 8,
#  'DXC': 8,
#  'ETSY': 8,
#  'FSLR': 8,
#  'ETRN': 8,
#  'FTNT': 8,
#  'HLT': 8,
#  'HRTX': 8,
#  'IOVA': 8,
#  'KEY': 8,
#  'LGIH': 8,
#  'M': 8,
#  'MOMO': 8,
#  'MOS': 8,
#  'PLAY': 8,
#  'PINS': 8,
#  'PBI': 8,
#  'PVH': 8,
#  'SAGE': 8,
#  'SEDG': 8,
#  'SNAP': 8,
#  'SRPT': 8,
#  'SPR': 8,
#  'TER': 8,
#  'TWLO': 8,
#  'TTM': 8,
#  'WB': 8,
#  'W': 8,
#  'VIAC': 8,
#  'ZYNE': 8,
#  'NASDAQ': 9,
#  'ACAD': 9,
#  'ANET': 9,
#  'AMAT': 9,
#  'BIDU': 9,
#  'BYND': 9,
#  'BXP': 9,
#  'CHX': 9,
#  'CHEF': 9,
#  'CLF': 9,
#  'CPRI': 9,
#  'DFS': 9,
#  'DRI': 9,
#  'DXCM': 9,
#  'EBAY': 9,
#  'ET': 9,
#  'EOG': 9,
#  'F': 9,
#  'GTHX': 9,
#  'HAL': 9,
#  'HBAN': 9,
#  'HP': 9,
#  'ILMN': 9,
#  'IDXX': 9,
#  'LPL': 9,
#  'LYFT': 9,
#  'LRCX': 9,
#  'MFGP': 9,
#  'MU': 9,
#  'MS': 9,
#  'MTCH': 9,
#  'NRG': 9,
#  'PUMP': 9,
#  'SIG': 9,
#  'SMAR': 9,
#  'TTD': 9,
#  'TWOU': 9,
#  'USFD': 9,
#  'VIPS': 9,
#  'URI': 9,
#  'ZM': 9,
#  'ALB': 10,
#  'ARWR': 10,
#  'BKR': 10,
#  'DOCU': 10,
#  'TWTR': 10,
#  'VALE': 10,
#  'AA': 11,
#  'CRWD': 11,
#  'DDOG': 11,
#  'ENPH': 11,
#  'GS': 11,
#  'LB': 11,
#  'LTHM': 11,
#  'MDB': 11,
#  'MAC': 11,
#  'NTNX': 11,
#  'RRC': 11,
#  'CLR': 12,
#  'DDS': 12,
#  'DVN': 12,
#  'NET': 12,
#  'OII': 12,
#  'OXY': 12,
#  'PTON': 12,
#  'PTR': 12,
#  'REGI': 12,
#  'SLB': 12,
#  'UPWK': 12,
#  'EQT': 13,
#  'NVDA': 13,
#  'OVV': 13,
#  'ROKU': 13,
#  'MRNA': 14,
#  'SPCE': 14}

# %%
#yfinfo['JP']
download_ticker_info('Z')
# Out:
# {'zip': '98101',
#  'sector': 'Communication Services',
#  'fullTimeEmployees': 5868,
#  'longBusinessSummary': "Zillow Group, Inc., a digital real estate company, operates real estate brands on mobile applications and websites in the United States. It operates through three segments: Homes; Internet, Media & Technology; and Mortgages. The company's mobile applications and websites offer various real estate transactions and related services, including buying, selling, renting, and financing services for residential real estate properties; purchase and sell homes; offer title and escrow services, title insurance products and services, and mortgage loans. Its portfolio of brands include Zillow, Zillow Offers, Zillow Closing Services, Zillow Home Loans, Trulia, StreetEasy, and HotPads. Zillow Group, Inc. was incorporated in 2004 and is headquartered in Seattle, Washington.",
#  'city': 'Seattle',
#  'phone': '206-470-7000',
#  'state': 'WA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.zillowgroup.com',
#  'maxAge': 86400,
#  'address1': '1301 Second Avenue',
#  'industry': 'Internet Content & Information',
#  'address2': 'Floor 31'}
