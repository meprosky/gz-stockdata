# %%
from gz_import import *
from gz_mainlib import *
from gz_plotlib import *
from gz_dwnllib import *
from gz_rwlib import *
from gz_const import *

mainver()
plotver()
rwver()
dwnlver()
constver()
# Out:
# Main ver: 67
# Plot ver: 67
# RW ver: 67
# Download ver: 69
# Const ver: 68

# %%
l_industries
# Out:
# ['Advertising Agencies',
#  'Aerospace & Defense',
#  'Agricultural Inputs',
#  'Airlines',
#  'Aluminum',
#  'Apparel Manufacturing',
#  'Apparel Retail',
#  'Asset Management',
#  'Auto & Truck Dealerships',
#  'Auto Manufacturers',
#  'Auto Parts',
#  'Banks—Diversified',
#  'Banks—Regional',
#  'Beverages—Brewers',
#  'Beverages—Non-Alcoholic',
#  'Beverages—Wineries & Distilleries',
#  'Biotechnology',
#  'Broadcasting',
#  'Building Materials',
#  'Building Products & Equipment',
#  'Business Equipment & Supplies',
#  'Capital Markets',
#  'Chemicals',
#  'Communication Equipment',
#  'Computer Hardware',
#  'Confectioners',
#  'Conglomerates',
#  'Consulting Services',
#  'Consumer Electronics',
#  'Copper',
#  'Credit Services',
#  'Department Stores',
#  'Diagnostics & Research',
#  'Discount Stores',
#  'Drug Manufacturers—General',
#  'Drug Manufacturers—Specialty & Generic',
#  'Education & Training Services',
#  'Electrical Equipment & Parts',
#  'Electronic Components',
#  'Electronic Gaming & Multimedia',
#  'Electronics & Computer Distribution',
#  'Engineering & Construction',
#  'Entertainment',
#  'Farm & Heavy Construction Machinery',
#  'Farm Products',
#  'Financial Conglomerates',
#  'Financial Data & Stock Exchanges',
#  'Food Distribution',
#  'Footwear & Accessories',
#  'Furnishings, Fixtures & Appliances',
#  'Gambling',
#  'Gold',
#  'Grocery Stores',
#  'Health Information Services',
#  'Healthcare Plans',
#  'Home Improvement Retail',
#  'Household & Personal Products',
#  'Industrial Distribution',
#  'Information Technology Services',
#  'Insurance Brokers',
#  'Insurance—Diversified',
#  'Insurance—Life',
#  'Insurance—Property & Casualty',
#  'Insurance—Reinsurance',
#  'Insurance—Specialty',
#  'Integrated Freight & Logistics',
#  'Internet Content & Information',
#  'Internet Retail',
#  'Leisure',
#  'Lodging',
#  'Lumber & Wood Production',
#  'Luxury Goods',
#  'Marine Shipping',
#  'Medical Care Facilities',
#  'Medical Devices',
#  'Medical Distribution',
#  'Medical Instruments & Supplies',
#  'Metal Fabrication',
#  'Mortgage Finance',
#  'Oil & Gas Drilling',
#  'Oil & Gas E&P',
#  'Oil & Gas Equipment & Services',
#  'Oil & Gas Integrated',
#  'Oil & Gas Midstream',
#  'Oil & Gas Refining & Marketing',
#  'Other Industrial Metals & Mining',
#  'Packaged Foods',
#  'Packaging & Containers',
#  'Paper & Paper Products',
#  'Personal Services',
#  'Pharmaceutical Retailers',
#  'Publishing',
#  'REIT—Diversified',
#  'REIT—Healthcare Facilities',
#  'REIT—Hotel & Motel',
#  'REIT—Industrial',
#  'REIT—Office',
#  'REIT—Residential',
#  'REIT—Retail',
#  'REIT—Specialty',
#  'Railroads',
#  'Real Estate Services',
#  'Real Estate—Diversified',
#  'Recreational Vehicles',
#  'Rental & Leasing Services',
#  'Residential Construction',
#  'Resorts & Casinos',
#  'Restaurants',
#  'Scientific & Technical Instruments',
#  'Security & Protection Services',
#  'Semiconductor Equipment & Materials',
#  'Semiconductors',
#  'Software—Application',
#  'Software—Infrastructure',
#  'Solar',
#  'Specialty Business Services',
#  'Specialty Chemicals',
#  'Specialty Industrial Machinery',
#  'Specialty Retail',
#  'Staffing & Employment Services',
#  'Steel',
#  'Telecom Services',
#  'Textile Manufacturing',
#  'Tobacco',
#  'Tools & Accessories',
#  'Travel Services',
#  'Trucking',
#  'Utilities—Diversified',
#  'Utilities—Independent Power Producers',
#  'Utilities—Regulated Electric',
#  'Utilities—Regulated Gas',
#  'Utilities—Regulated Water',
#  'Waste Management']

# %%
for x in l_industries:
    print(x, d_industry_tics[x])
# Out:
# Advertising Agencies ['DLX', 'IPG', 'OMC', 'QNST', 'QUOT']
# Aerospace & Defense ['AIR', 'AJRD', 'ATRO', 'AVAV', 'AXON', 'BA', 'BWXT', 'GD', 'HEI', 'HII', 'HXL', 'LHX', 'LMT', 'NOC', 'NPK', 'RGR', 'RTX', 'SPCE', 'SPR', 'SWBI', 'TDG', 'TXT', 'WWD']
# Agricultural Inputs ['CF', 'CTVA', 'FMC', 'MOS', 'SMG']
# Airlines ['AAL', 'ALGT', 'ALK', 'CEA', 'DAL', 'HA', 'LUV', 'SAVE', 'UAL', 'ZNH']
# Aluminum ['AA', 'ACH', 'KALU']
# Apparel Manufacturing ['COLM', 'CPRI', 'HBI', 'KTB', 'LEVI', 'PVH', 'RL', 'UA', 'UAA', 'VFC']
# Apparel Retail ['AEO', 'ANF', 'BOOT', 'BURL', 'CRI', 'DLTH', 'GCO', 'GPS', 'LB', 'LULU', 'PLCE', 'ROST', 'TJX', 'URBN', 'ZUMZ']
# Asset Management ['AMG', 'AMP', 'ARCC', 'BEN', 'BK', 'BLK', 'BX', 'CNS', 'IVZ', 'NTRS', 'SEIC', 'STT', 'TROW', 'VRTS']
# Auto & Truck Dealerships ['ABG', 'AN', 'CARS', 'CRMT', 'GPI', 'KMX', 'LAD']
# Auto Manufacturers ['F', 'GM', 'LI', 'RACE', 'RIDE', 'TM', 'TSLA', 'TTM', 'WKHS']
# Auto Parts ['ALSN', 'ALV', 'APTV', 'BWA', 'CPS', 'DORM', 'GT', 'GTX', 'HYLN', 'LEA', 'LKQ', 'MNRO', 'MTOR', 'QS', 'SRI', 'THRM', 'VC', 'VNE']
# Banks—Diversified ['BAC', 'C', 'EWBC', 'JPM', 'WFC']
# Banks—Regional ['AX', 'BOH', 'BOKF', 'CBSH', 'CBU', 'CFG', 'CFR', 'CHCO', 'CMA', 'FCNCA', 'FITB', 'GBCI', 'HBAN', 'IBN', 'INDB', 'KEY', 'MTB', 'NCBS', 'PB', 'PBCT', 'PNC', 'PNFP', 'RF', 'RRBI', 'SBCF', 'SI', 'SIVB', 'TCBI', 'TFC', 'UMBF', 'USB', 'WABC', 'WAL', 'WBS', 'WTFC', 'ZION']
# Beverages—Brewers ['BUD', 'SAM', 'TAP']
# Beverages—Non-Alcoholic ['COKE', 'FIZZ', 'KDP', 'KO', 'MNST', 'PEP']
# Beverages—Wineries & Distilleries ['STZ']
# Biotechnology ['ACAD', 'ADPT', 'AFMD', 'AGIO', 'ALLK', 'ALLO', 'ALNY', 'ALXN', 'ALXO', 'AMTI', 'ANAB', 'ANIK', 'APLT', 'ARCT', 'ARNA', 'ARQT', 'ARVN', 'ARWR', 'ATRA', 'AXSM', 'BBIO', 'BDTX', 'BLUE', 'BMRN', 'BPMC', 'BTAI', 'CARA', 'CCXI', 'CGEN', 'CNST', 'CORT', 'CRSP', 'CRTX', 'CVM', 'DCPH', 'DNLI', 'DRNA', 'EDIT', 'ENTA', 'ESPR', 'EXEL', 'FATE', 'FGEN', 'FOLD', 'GBT', 'GOSS', 'GTHX', 'HALO', 'HRTX', 'ICPT', 'IGMS', 'INCY', 'IONS', 'IOVA', 'ITCI', 'KOD', 'KRTX', 'KRYS', 'LGND', 'MDGL', 'MRNA', 'MRTX', 'NBIX', 'NKTR', 'NRIX', 'NTLA', 'PRAX', 'PRTA', 'PTCT', 'RARE', 'REGN', 'RETA', 'RGNX', 'RYTM', 'SAGE', 'SAVA', 'SGEN', 'SRPT', 'TCRR', 'TECH', 'TPTX', 'UTHR', 'VCEL', 'VCYT', 'VIR', 'VNDA', 'VRTX', 'VXRT', 'XLRN', 'XNCR', 'ZGNX']
# Broadcasting ['AMCX', 'FOX', 'FOXA', 'GTN', 'NWS', 'NWSA', 'NXST', 'SBGI', 'TGNA']
# Building Materials ['EXP', 'MLM', 'VMC']
# Building Products & Equipment ['AAON', 'AWI', 'BECN', 'BLDR', 'CARR', 'CSL', 'GMS', 'IBP', 'JELD', 'LPX', 'MAS', 'OC', 'PGTI', 'ROCK', 'SSD', 'TREX']
# Business Equipment & Supplies ['AVY', 'PBI']
# Capital Markets ['COWN', 'EVR', 'FOCS', 'FRHC', 'GS', 'HLI', 'IBKR', 'LPLA', 'MKTX', 'MS', 'PIPR', 'RJF', 'SCHW', 'SF', 'TW', 'VIRT']
# Chemicals ['APD', 'ASIX', 'CE', 'DOW', 'EMN', 'MTX', 'UNVR']
# Communication Equipment ['CIEN', 'CSCO', 'HPE', 'INSG', 'JNPR', 'LITE', 'MSI', 'NOK', 'NTGR', 'UI', 'VCRA', 'VSAT', 'ZBRA']
# Computer Hardware ['ANET', 'DELL', 'HPQ', 'NTAP', 'PSTG', 'STX', 'WDC']
# Confectioners ['HSY', 'MDLZ']
# Conglomerates ['VRTV']
# Consulting Services ['BAH', 'EFX', 'EXPO', 'FCN', 'FORR', 'HURN', 'INFO', 'NLSN', 'TRU', 'VRSK']
# Consumer Electronics ['AAPL', 'HEAR', 'IRBT', 'LPL', 'SONO', 'SONY', 'VUZI', 'VZIO']
# Copper ['FCX', 'SCCO']
# Credit Services ['ADS', 'ALLY', 'AXP', 'CACC', 'COF', 'DFS', 'FCFS', 'GDOT', 'MA', 'NAVI', 'PRAA', 'PYPL', 'SYF', 'V', 'WRLD', 'WU']
# Department Stores ['DDS', 'JWN', 'M']
# Diagnostics & Research ['A', 'AWH', 'BNGO', 'CDNA', 'CRL', 'DGX', 'DHR', 'DMTK', 'DXCM', 'EXAS', 'GH', 'HSKA', 'IDXX', 'ILMN', 'IQV', 'LH', 'LNTH', 'MEDP', 'MTD', 'MYGN', 'NEO', 'NEOG', 'NTRA', 'NVTA', 'PKI', 'PRAH', 'QDEL', 'SYNH', 'TMO', 'WAT']
# Discount Stores ['BIG', 'COST', 'DG', 'DLTR', 'OLLI', 'TGT', 'WMT']
# Drug Manufacturers—General ['ABBV', 'AMGN', 'BIIB', 'BMY', 'GILD', 'JNJ', 'LLY', 'MRK', 'NVS', 'OGN', 'PFE', 'SNY']
# Drug Manufacturers—Specialty & Generic ['AERI', 'ANIP', 'CTLT', 'EBS', 'EGRX', 'ELAN', 'ENDP', 'PCRX', 'PETQ', 'RDY', 'SLDB', 'SUPN', 'TAK', 'VTRS', 'ZTS', 'ZYNE']
# Education & Training Services ['APEI', 'ATGE', 'CHGG', 'COUR', 'GHC', 'LOPE', 'LRN', 'STRA', 'TAL', 'TWOU']
# Electrical Equipment & Parts ['AEIS', 'ATKR', 'AYI', 'BDC', 'BMI', 'ENR', 'ENS', 'HUBB']
# Electronic Components ['APH', 'GLW', 'JBL', 'KOPN', 'LFUS', 'MEI', 'OSIS', 'PLXS', 'ROG', 'TEL', 'TTMI', 'VICR']
# Electronic Gaming & Multimedia ['ATVI', 'BILI', 'EA', 'SKLZ', 'TTWO']
# Electronics & Computer Distribution ['ARW', 'AVT', 'CNXN', 'SCSC']
# Engineering & Construction ['ACM', 'BLD', 'DY', 'EME', 'FLR', 'GVA', 'J', 'JCI', 'MYRG', 'NVEE', 'PWR', 'TTEK']
# Entertainment ['CHTR', 'CMCSA', 'CNK', 'DIS', 'DISCA', 'DISCB', 'DISCK', 'DISH', 'LBRDK', 'LYV', 'MSGE', 'MSGN', 'MSGS', 'NFLX', 'ROKU', 'VIAC', 'WWE']
# Farm & Heavy Construction Machinery ['AGCO', 'ALG', 'CAT', 'CMCO', 'DE', 'LNN', 'OSK', 'PCAR']
# Farm Products ['ADM', 'APPH', 'CALM', 'TSN']
# Financial Conglomerates ['JEF']
# Financial Data & Stock Exchanges ['CME', 'FDS', 'ICE', 'MCO', 'MORN', 'MSCI', 'NDAQ', 'SPGI']
# Food Distribution ['ANDE', 'CHEF', 'PFGC', 'SYY', 'USFD']
# Footwear & Accessories ['CROX', 'DECK', 'FL', 'NKE', 'SKX', 'WWW']
# Furnishings, Fixtures & Appliances ['AMWD', 'FBHS', 'LEG', 'MHK', 'MLHR', 'SNBR', 'TPX', 'WHR']
# Gambling ['CHDN', 'DKNG']
# Gold ['NEM', 'RGLD']
# Grocery Stores ['CASY', 'GO', 'KR', 'SFM']
# Health Information Services ['CERN', 'CHNG', 'CVET', 'EVH', 'GDRX', 'HQY', 'MDRX', 'OMCL', 'PGNY', 'PINC', 'SDGR', 'SLP', 'TDOC', 'TRHC', 'TXG', 'VEEV']
# Healthcare Plans ['ANTM', 'CI', 'CLOV', 'CNC', 'CVS', 'HUM', 'MGLN', 'MOH', 'UNH']
# Home Improvement Retail ['FND', 'HD', 'LOW']
# Household & Personal Products ['CHD', 'CL', 'CLX', 'COTY', 'EL', 'EPC', 'IPAR', 'KMB', 'NTCO', 'NUS', 'NWL', 'PG', 'USNA']
# Industrial Distribution ['AIT', 'FAST', 'GWW', 'MSM', 'SITE', 'WCC', 'WSO']
# Information Technology Services ['ACN', 'BR', 'CDW', 'CNXC', 'CTSH', 'DLB', 'DXC', 'EPAM', 'EXLS', 'FIS', 'FISV', 'FLT', 'IBM', 'IT', 'JKHY', 'LDOS', 'NCR', 'PRFT', 'RAMP', 'SAIC', 'SNX', 'SWCH', 'SYKE', 'TDC', 'TRIT', 'XRX']
# Insurance Brokers ['AJG', 'AON', 'BRO', 'CRVL', 'EHTH', 'ERIE', 'MMC', 'WLTW']
# Insurance—Diversified ['AIG', 'GSHD', 'HIG', 'PFG']
# Insurance—Life ['AFL', 'BHF', 'GL', 'LFC', 'MET', 'NWLI', 'PRI', 'PRU', 'UNM']
# Insurance—Property & Casualty ['AFG', 'ALL', 'CB', 'CINF', 'KMPR', 'KNSL', 'L', 'MKL', 'NMIH', 'PGR', 'SIGI', 'THG', 'TRV', 'WRB', 'Y']
# Insurance—Reinsurance ['RE', 'RGA']
# Insurance—Specialty ['AIZ', 'AMSF', 'FNF', 'MTG', 'TRUP']
# Integrated Freight & Logistics ['CHRW', 'ECHO', 'EXPD', 'FDX', 'FWRD', 'HUBG', 'JBHT', 'LSTR', 'UPS', 'XPO']
# Internet Content & Information ['ABNB', 'ANGI', 'BIDU', 'CARG', 'CDLX', 'DASH', 'EVER', 'FB', 'GOOG', 'GOOGL', 'IAC', 'MOMO', 'MTCH', 'NTES', 'PINS', 'SNAP', 'SOHU', 'SPOT', 'SSTK', 'TWLO', 'TWTR', 'WB', 'YELP', 'YY', 'Z', 'ZG']
# Internet Retail ['AMZN', 'BABA', 'BZUN', 'CHWY', 'CPNG', 'CVNA', 'EBAY', 'ETSY', 'FTCH', 'GRUB', 'JD', 'MELI', 'POSH', 'PRTS', 'QRTEA', 'RVLV', 'VIPS', 'W', 'WISH']
# Leisure ['AOUT', 'BC', 'FNKO', 'HAS', 'JOUT', 'MANU', 'MAT', 'PLNT', 'POOL', 'PTON', 'YETI']
# Lodging ['CHH', 'H', 'HLT', 'HTHT', 'MAR', 'WH']
# Lumber & Wood Production ['UFPI']
# Luxury Goods ['MOV', 'SIG', 'TPR']
# Marine Shipping ['KEX', 'MATX']
# Medical Care Facilities ['ADUS', 'AMED', 'AMN', 'CHE', 'DVA', 'HCA', 'HCSG', 'LHCG', 'MD', 'MODV', 'PNTG', 'UHS', 'USPH']
# Medical Devices ['ABMD', 'ABT', 'ALGN', 'AVNS', 'AXGN', 'BIO', 'BRKR', 'BSX', 'CNMD', 'CSII', 'EAR', 'EW', 'GMED', 'IART', 'INGN', 'INMD', 'INSP', 'ITGR', 'KIDS', 'MDT', 'NARI', 'NTUS', 'NUVA', 'NVRO', 'OFIX', 'PEN', 'PODD', 'SRDX', 'SWAV', 'SYK', 'TCMD', 'TNDM', 'VREX', 'ZBH', 'ZYXI']
# Medical Distribution ['ABC', 'CAH', 'HSIC', 'MCK', 'PBH', 'PDCO']
# Medical Instruments & Supplies ['ATRC', 'ATRI', 'BAX', 'BDX', 'COO', 'GKOS', 'HAE', 'HOLX', 'HRC', 'ICUI', 'IRTC', 'ISRG', 'MASI', 'MMSI', 'NVCR', 'OSUR', 'RGEN', 'RMD', 'STAA', 'STE', 'TFX', 'WST', 'XRAY']
# Metal Fabrication ['CRS', 'PRLB', 'VMI', 'WOR']
# Mortgage Finance ['ECPG', 'TREE']
# Oil & Gas Drilling ['HP', 'RIG']
# Oil & Gas E&P ['APA', 'CHK', 'CLR', 'COG', 'COP', 'DVN', 'EOG', 'EQT', 'FANG', 'HES', 'MGY', 'MRO', 'MUR', 'OVV', 'OXY', 'PXD', 'RRC', 'SWN', 'XEC']
# Oil & Gas Equipment & Services ['BKR', 'CHX', 'DNOW', 'DRQ', 'FTI', 'HAL', 'MRC', 'NOV', 'OII', 'OIS', 'PUMP', 'SLB', 'WHD', 'WTTR']
# Oil & Gas Integrated ['CVX', 'PTR', 'XOM']
# Oil & Gas Midstream ['ET', 'ETRN', 'KMI', 'OKE', 'WMB']
# Oil & Gas Refining & Marketing ['DK', 'HFC', 'MPC', 'PBF', 'PSX', 'REGI', 'REX', 'SHI', 'VLO']
# Other Industrial Metals & Mining ['CMP', 'MTRN', 'VALE']
# Packaged Foods ['BGS', 'BYND', 'CAG', 'CENT', 'CENTA', 'CPB', 'CVGW', 'DAR', 'FRPT', 'GIS', 'HAIN', 'HRL', 'INGR', 'JBSS', 'JJSF', 'K', 'KHC', 'LANC', 'LW', 'MKC', 'POST', 'PPC', 'SAFM', 'SJM', 'SMPL', 'THS', 'TTCF', 'TWNK']
# Packaging & Containers ['ATR', 'BERY', 'BLL', 'CCK', 'GEF', 'IP', 'OI', 'PKG', 'SEE', 'SON', 'WRK']
# Paper & Paper Products ['NP', 'UFS']
# Personal Services ['BFAM', 'FTDR', 'HRB', 'MED', 'ROL', 'SCI', 'TMX']
# Pharmaceutical Retailers ['WBA']
# Publishing ['NYT']
# REIT—Diversified ['CORR', 'SRC']
# REIT—Healthcare Facilities ['HTA', 'OHI', 'PEAK', 'SBRA', 'VTR', 'WELL']
# REIT—Hotel & Motel ['APLE', 'CLDT', 'HST']
# REIT—Industrial ['COLD', 'DRE', 'EXR', 'IIPR', 'PLD', 'PSA', 'QTS', 'STAG']
# REIT—Office ['ARE', 'BXP', 'COR', 'DLR', 'GNL', 'SLG', 'VNO']
# REIT—Residential ['AIRC', 'AIV', 'AVB', 'ELS', 'ESS', 'INVH', 'MAA', 'UDR']
# REIT—Retail ['KIM', 'KRG', 'MAC', 'O', 'REG', 'SPG']
# REIT—Specialty ['AMT', 'CCI', 'CONE', 'EQIX', 'IRM', 'RYN', 'SBAC', 'WY']
# Railroads ['CSX', 'GBX', 'KSU', 'NSC', 'UNP', 'WAB']
# Real Estate Services ['CBRE', 'CSGP', 'FRPH', 'JLL', 'MMI', 'RDFN']
# Real Estate—Diversified ['HHC']
# Recreational Vehicles ['FOXF', 'HOG', 'LCII', 'MBUU', 'PATK', 'PII', 'THO', 'WGO']
# Rental & Leasing Services ['GATX', 'PRG', 'R', 'URI', 'WSC']
# Residential Construction ['CVCO', 'DHI', 'KBH', 'LEGH', 'LEN', 'LGIH', 'MHO', 'MTH', 'NVR', 'PHM', 'TMHC', 'TOL', 'TPH']
# Resorts & Casinos ['HGV', 'LVS', 'MCRI', 'MGM', 'MLCO', 'MTN', 'VAC', 'WYNN']
# Restaurants ['ARMK', 'BH', 'BJRI', 'CBRL', 'CMG', 'DPZ', 'DRI', 'EAT', 'JACK', 'MCD', 'PLAY', 'PZZA', 'RRGB', 'SBUX', 'SHAK', 'TXRH', 'WING', 'YUM', 'YUMC']
# Scientific & Technical Instruments ['CGNX', 'COHR', 'ESE', 'FARO', 'FTV', 'GRMN', 'IIVI', 'ITRI', 'KEYS', 'MKSI', 'MLAB', 'MVIS', 'TDY', 'TRMB', 'VLDR', 'VNT', 'VPG']
# Security & Protection Services ['ALLE', 'BCO', 'BRC', 'MSA', 'REZI']
# Semiconductor Equipment & Materials ['ACMR', 'AMAT', 'BRKS', 'CCMP', 'ENTG', 'IPGP', 'KLAC', 'LRCX', 'OLED', 'TER', 'UCTT']
# Semiconductors ['ADI', 'AMD', 'AVGO', 'CEVA', 'CREE', 'CRUS', 'DIOD', 'FORM', 'INTC', 'LASR', 'LSCC', 'MCHP', 'MPWR', 'MRVL', 'MU', 'MXIM', 'MXL', 'NVDA', 'NXPI', 'ON', 'ONTO', 'POWI', 'QCOM', 'QRVO', 'SLAB', 'SMTC', 'SWKS', 'SYNA', 'TSM', 'TXN', 'XLNX']
# Software—Application ['ADSK', 'ALRM', 'ANSS', 'APPF', 'APPS', 'AVLR', 'AYX', 'AZPN', 'BILL', 'BLKB', 'CDK', 'CDNS', 'CLDR', 'CLSK', 'COIN', 'COUP', 'CRM', 'CSOD', 'CTXS', 'CVLT', 'DDOG', 'DOCU', 'DT', 'EGHT', 'ENV', 'EVBG', 'FICO', 'FSLY', 'GWRE', 'HUBS', 'INTU', 'LAZR', 'LPSN', 'LYFT', 'MANH', 'MANT', 'MDLA', 'MSTR', 'NATI', 'NOW', 'PAYC', 'PCTY', 'PD', 'PEGA', 'PLUS', 'PRGS', 'PTC', 'QADA', 'QTWO', 'RNG', 'RPD', 'SAP', 'SMAR', 'SSNC', 'STMP', 'TTD', 'TYL', 'UBER', 'WDAY', 'WK', 'WORK', 'ZEN', 'ZI', 'ZM']
# Software—Infrastructure ['ADBE', 'AKAM', 'ALTR', 'APPN', 'BAND', 'BKI', 'BL', 'BOX', 'CGNT', 'CHKP', 'CRWD', 'CSGS', 'DBX', 'EEFT', 'EPAY', 'FFIV', 'FIVN', 'FTNT', 'GDDY', 'GSKY', 'JCOM', 'MDB', 'MFGP', 'MQ', 'MSFT', 'NET', 'NEWR', 'NLOK', 'NTCT', 'NTNX', 'OKTA', 'ORCL', 'PAGS', 'PANW', 'PFPT', 'PLAN', 'PLTR', 'QLYS', 'SAIL', 'SNPS', 'SPLK', 'SPSC', 'SQ', 'SQSP', 'SWI', 'TCX', 'TENB', 'VMW', 'VRNS', 'VRNT', 'VRSN', 'WEX', 'YEXT', 'ZS', 'ZUO']
# Solar ['ENPH', 'FSLR', 'FTCI', 'RUN', 'SEDG']
# Specialty Business Services ['CPRT', 'CTAS', 'GPN', 'MMS', 'SP', 'UNF']
# Specialty Chemicals ['ALB', 'ASH', 'AVNT', 'AVTR', 'BCPC', 'DD', 'ECL', 'FOE', 'FUL', 'GCP', 'GEVO', 'GRA', 'IFF', 'IOSP', 'KWR', 'LIN', 'LTHM', 'LYB', 'NEU', 'NGVT', 'PPG', 'RPM', 'SHW', 'SXT', 'WDFC', 'WLK']
# Specialty Industrial Machinery ['AME', 'AOS', 'ARNC', 'CFX', 'CMI', 'CR', 'CSWI', 'CW', 'DCI', 'DOV', 'EMR', 'ETN', 'FELE', 'FLOW', 'FLS', 'GE', 'GGG', 'GNRC', 'GTLS', 'HON', 'HSC', 'HWM', 'IEX', 'IR', 'ITT', 'ITW', 'JBT', 'LII', 'MIDD', 'MMM', 'NDSN', 'OTIS', 'PH', 'PSN', 'RAVN', 'RBC', 'ROK', 'ROP', 'RXN', 'SXI', 'TNC', 'TPIC', 'TT', 'WTS', 'XYL']
# Specialty Retail ['AAN', 'AAP', 'ASO', 'AZO', 'BBBY', 'BBY', 'BLNK', 'DKS', 'EYE', 'FLWS', 'GPC', 'HIBB', 'MUSA', 'ORLY', 'RH', 'SBH', 'SFIX', 'TCS', 'TSCO', 'ULTA', 'WSM']
# Staffing & Employment Services ['ADP', 'ASGN', 'BBSI', 'HHR', 'JOBS', 'KFY', 'MAN', 'NSP', 'RHI', 'TNET', 'UPWK', 'ZIP']
# Steel ['CLF', 'CMC', 'NUE', 'RS', 'STLD']
# Telecom Services ['ATEX', 'ATNI', 'ATUS', 'CABO', 'CCOI', 'IDCC', 'IRDM', 'LUMN', 'MBT', 'SHEN', 'SKM', 'T', 'TDS', 'TMUS', 'USM', 'VEON', 'VG', 'VZ']
# Textile Manufacturing ['AIN']
# Tobacco ['BTI', 'MO', 'PM']
# Tools & Accessories ['KMT', 'LECO', 'ROLL', 'SNA', 'SWK', 'TKR', 'TTC']
# Travel Services ['BKNG', 'CCL', 'EXPE', 'RCL', 'TNL', 'TRIP']
# Trucking ['KNX', 'ODFL', 'SAIA', 'WERN']
# Utilities—Diversified ['AES', 'ALE', 'EXC', 'NWE', 'PEG', 'SJI', 'SRE', 'UTL']
# Utilities—Independent Power Producers ['HNP', 'NRG']
# Utilities—Regulated Electric ['AEE', 'CMS', 'CNP', 'D', 'ED', 'EIX', 'ES', 'ETR', 'EVRG', 'KEP', 'LNT', 'NEE', 'OGE', 'PCG', 'POR', 'PPL', 'SO', 'WEC', 'XEL']
# Utilities—Regulated Gas ['NFE', 'NJR', 'OGS', 'SR', 'SWX', 'UGI']
# Utilities—Regulated Water ['AWK', 'AWR', 'CWT', 'SJW']
# Waste Management ['CLH', 'CWST', 'HCCI', 'RSG', 'SRCL', 'WM']

# %%
dfy = pd.read_hdf('dat.h5', 'dfy')
dfm = pd.read_hdf('dat.h5', 'dfm')
dfy_doclh = pd.read_hdf('dat.h5', 'dfy_doclh')
dfm_doclh = pd.read_hdf('dat.h5', 'dfm_doclh')
dfy_corr = pd.read_hdf('dat.h5', 'dfy_corr')
dfm_corr = pd.read_hdf('dat.h5', 'dfm_corr')
dfm_coint = pd.read_hdf('dat.h5', 'dfm_coint')
dfy_coint = pd.read_hdf('dat.h5', 'dfy_coint')

# %%
dfy_corr[dfy_corr['SP500'] > 0.8]['SP500']
# Out:
# SP500     1.000000
# NASDAQ    0.945366
# AAPL      0.804773
# ACN       0.854396
# AVGO      0.808722
# EXC       0.804671
# GLW       0.833246
# GOOGL     0.817477
# GOOG      0.815031
# GPN       0.811480
# GRMN      0.807054
# HD        0.821103
# JOYY      0.871654
# MA        0.832730
# MS        0.821473
# MSFT      0.857810
# SBUX      0.816079
# TROW      0.819629
# TXN       0.829323
# V         0.865923
# Name: SP500, dtype: float64
